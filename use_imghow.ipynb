# %%
# random picture
import matplotlib.pyplot as plt
import numpy as np

# create a 2D array of random pixel values
image = np.random.rand(20, 20)

# display the image using plt.imshow()
#plt.imshow(image, cmap='gray')

plt.imshow(image)

# show the plot
plt.show()
